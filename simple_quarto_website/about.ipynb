# %% [raw]
# ---
# title: "About"
# ---

# %% [markdown]
# # h1
#
# This is h1
#
# ## h2
#
# This is h2
#
# ## h3
#
# This is h3

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fig.set_facecolor('gray')

ax.set_title('test')

ax.axis('off')

plt.show()
